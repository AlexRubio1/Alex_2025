# %% [raw]
# ---
# layout: post
# title: Blog for homework
# description: Navigation to get from homework to homework and summary
# courses: { csp: {week:1} }
# comments: true
# sticky_rank: 1
# ---

# %% [markdown]
# ## Website Navigation Table
#
# This table provides quick links to various sections of the website, including lesson pages, blogs, and homework assignments. Each row represents a different section or lesson, making it easy to navigate through the content. The soft pastel colors and hover effects offer a clean and modern look while keeping the user experience smooth and intuitive. Below is the overview of the sections:
#
# - **Home**: The main landing page of the site.
# - **Blog Main Page**: Explore the latest blog posts.
#
# Each lesson link redirects to its specific page/ team teach.
#
# > Feel free to browse through the table to explore the lessons and blog posts!

# %% [markdown]
# <style>
#     table {
#         width: 100%;
#         border-collapse: collapse;
#         font-family: 'Arial', sans-serif;
#         font-size: 16px;
#         margin-bottom: 20px;
#     }
#
#     th, td {
#         border: 1px solid #cccccc;
#         text-align: left;
#         padding: 12px;
#     }
#
#     th {
#         background-color: #77c6ff; /* Soft blue for header */
#         color: white;
#         text-transform: uppercase;
#         border-radius: 10px 10px 0 0; /* Rounded top corners for header */
#     }
#
#     tr:nth-child(even) {
#         background-color: #f0f8ff; /* Light blue for alternating rows */
#     }
#
#     tr:nth-child(odd) {
#         background-color: #e7f6ff; /* Slightly different shade for odd rows */
#     }
#
#     tr:hover {
#         background-color: #b3e5ff; /* Blue hover effect */
#     }
#
#     td a {
#         color: #ff9c6b; /* Soft orange for links */
#         text-decoration: none;
#         font-weight: bold;
#     }
#
#     td a:hover {
#         color: #ff6f61; /* Darker orange on hover */
#         text-decoration: underline;
#     }
#
#     td {
#         border-radius: 5px;
#     }
# </style>
#
# <table>
#   <tr>
#     <th>Page</th>
#     <th>Description</th>
#     <th>Link</th>
#   </tr>
#   <tr>
#     <td>Home</td>
#     <td>Main landing page</td>
#     <td><a href="https://alexrubio1.github.io/Alex_2025/">Go to Home</a></td>
#   </tr>
#   <tr>
#     <td>Blog main page</td>
#     <td>Read my latest blog posts</td>
#     <td><a href="https://alexrubio1.github.io/Alex_2025/blogs/">Check my blogs</a></td>
#   </tr>
#   <tr>
#     <td>team teach 3.1</td>
#     <td>homeworks + popcorn hacks</td>
#     <td><a href="https://alexrubio1.github.io/Alex_2025/2024/10/07/team-teach-3-1_IPYNB_2_.html">Lesson 3.1</a></td>
#   </tr>
#   <tr>
#     <td>team teach 3.2</td>
#     <td>homeworks + popcorn hacks</td>
#     <td><a href="https://alexrubio1.github.io/Alex_2025/2024/10/07/team-teach-3-2_IPYNB_2_.html">Lesson 3.2</a></td>
#   </tr>
#   <tr>
#     <td>team teach 3.3</td>
#     <td>homeworks + popcorn hacks</td>
#     <td><a href="https://alexrubio1.github.io/Alex_2025/2024/10/09/team-teach-3-3_IPYNB_2_.html">Lesson 3.3</a></td>
#   </tr>
#   <tr>
#     <td>team teach 3.4</td>
#     <td>homeworks + popcorn hacks</td>
#     <td><a href="https://alexrubio1.github.io/Alex_2025/2024/10/10/team-teach-3-4_IPYNB_2_.html">Lesson 3.4</a></td>
#   </tr>
#   <tr>
#     <td>team teach 3.5</td>
#     <td>homeworks + popcorn hacks</td>
#     <td><a href="https://alexrubio1.github.io/Alex_2025/2024/10/10/team-teach-3-5_IPYNB_2_.html">Lesson 3.5</a></td>
#   </tr>
#   <tr>
#     <td>team teach 3.6</td>
#     <td>homeworks + popcorn hacks</td>
#     <td><a href="https://alexrubio1.github.io/Alex_2025/2024/10/10/team-teach-3-6_IPYNB_2_.html">Lesson 3.6</a></td>
#   </tr>
#   <tr>
#     <td>team teach 3.7</td>
#     <td>homeworks + popcorn hacks</td>
#     <td><a href="https://alexrubio1.github.io/Alex_2025/2024/10/10/team-teach-3-7_IPYNB_2_.html">Lesson 3.7</a></td>
#   </tr>
#   <tr>
#     <td>team teach 3.8</td>
#     <td>homeworks + popcorn hacks</td>
#     <td><a href="https://nighthawkcoders.github.io/portfolio_2025/csp/big-idea/p2/3-8">Lesson 3.8 (my lesson)</a></td>
#   </tr>
#   <tr>
#     <td>team teach 3.10</td>
#     <td>homeworks + popcorn hacks</td>
#     <td><a href="https://alexrubio1.github.io/Alex_2025/2024/10/03/team-teach-3-10_IPYNB_2_.html">Lesson 3.10</a></td>
#   </tr>
#   <tr>
#     <td>summary</td>
#     <td>summary of the all lessons</td>
#     <td><a href="https://alexrubio1.github.io/Alex_2025/2024/10/16/summary_IPYNB_2_.html">summary</a></td>
#   </tr>
#   <tr>
#     <td>summary</td>
#     <td>summary of sprint 2</td>
#     <td><a href="https://alexrubio1.github.io/Alex_2025/2024/10/21/excutive-summary_IPYNB_2_.html">excutive summary</a></td>
#   </tr>
# </table>

# %% [markdown]
# <style>
#     body {
#         background-color: #2e3440;  /* Dark background */
#         color: white;               /* White text */
#     }
#
#     div.code_cell {
#         background-color: #282a36;  /* Dark theme for code cells */
#         color: white;               /* White text for code cells */
#         border-radius: 10px;
#         padding: 10px;
#     }
#
#     div.markdown_cell {
#         background-color: #44475a;  /* Dark theme for markdown cells */
#         color: white;               /* White text for markdown cells */
#         border-radius: 10px;
#         padding: 10px;
#     }
#     </style>
