# %% [raw]
# ---
# layout: post
# title: Blog for homework
# description: Navigation to get from homework to homework and summary
# courses: { csp: {week:1} }
# comments: true
# sticky_rank: 1
# ---

# %% [markdown]
# # 🌟 Unlocking the Magic of HTML: 9 Clever Hacks 💻✨
#
# HTML is the backbone of the web, but there's more to it than meets the eye. With the right tricks up your sleeve, you can turn simple lines of code into something extraordinary. In this summary, we’ll reveal **9 creative hacks** that will not only streamline your coding but also make your websites stand out. Get ready to unlock hidden potential and discover new ways to breathe life into your web projects!
#
# ---
#
# ## 🔑 What You'll Learn
#
# - **Boost Efficiency**: Master time-saving techniques.
# - **Enhance User Experience**: Create smoother, more interactive interfaces.
# - **Optimize for Performance**: Make your websites load faster.
# - **Add Cool Effects**: Impress users with subtle animations and visuals.
#
# ---
#
# > 💡 *Pro Tip*: Keep experimenting with these hacks to uncover even more possibilities in HTML! Every line of code is an opportunity to innovate. 🌐
#
# Let’s dive in and start hacking your way to better websites! 🚀

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Expandable Horizontal Table Example</title>
    <style>
        table {
            width: 100%;
            border-collapse: collapse;
        }
        table, th, td {
            border: 1px solid black;
        }
        th, td {
            padding: 10px;
            text-align: left;
        }
        .expandable-column {
            display: none;
        }
        .expand-btn {
            cursor: pointer;
            background-color: #f2f2f2;
        }
    </style>
</head>
<body>

<h2>Expandable Horizontal Table</h2>

<table>
    <thead>
        <tr>
            <th class="expand-btn" onclick="toggleColumns(this)">+</th>
            <th>Name</th>
            <th>Age</th>
            <th>Occupation</th>
            <th class="expandable-column">Hobbies</th>
            <th class="expandable-column">Location</th>
        </tr>
    </thead>
    <tbody>
        <tr>
            <td class="expand-btn" onclick="toggleColumns(this)">+</td>
            <td>John Doe</td>
            <td>28</td>
            <td>Software Developer</td>
            <td class="expandable-column">Coding, Hiking</td>
            <td class="expandable-column">New York</td>
        </tr>
        <tr>
            <td class="expand-btn" onclick="toggleColumns(this)">+</td>
            <td>Jane Smith</td>
            <td>32</td>
            <td>Graphic Designer</td>
            <td class="expandable-column">Painting, Traveling</td>
            <td class="expandable-column">San Francisco</td>
        </tr>
    </tbody>
</table>

<script>
    function toggleColumns(button) {
        const expandableColumns = document.querySelectorAll('.expandable-column');
        let isExpanded = Array.from(expandableColumns).some(col => col.style.display === "table-cell");

        if (isExpanded) {
            expandableColumns.forEach(col => col.style.display = "none");
            button.textContent = "+";
        } else {
            expandableColumns.forEach(col => col.style.display = "table-cell");
            button.textContent = "-";
        }
    }
</script>

</body>
</html>
# Out:
#   Cell In[1], line 13
#     border: 1px solid black;
#             ^
# SyntaxError: invalid decimal literal
