# %% [raw]
# ---
# layout: post
# title: My summary of all team lessons/ studying topics
# description: team teach summary
# courses: { csp: {week:1} }
# comments: true
# sticky_rank: 1
# ---

# %% [markdown]
# ## Short summarys of lessons/flash cards to remember

# %% [markdown]
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>AP Computer Science Flashcards</title>
#     <style>
#         body {
#             font-family: Arial, sans-serif;
#             background-color: #f4f4f4;
#             padding: 20px;
#         }
#         .flashcard {
#             background-color: white;
#             border: 1px solid #dddddd;
#             border-radius: 5px;
#             padding: 15px;
#             margin: 10px 0;
#             box-shadow: 0 2px 5px rgba(0, 0, 0, 0.1);
#         }
#         .content {
#             display: none;
#             background-color: #e7f1ff;
#             padding: 10px;
#             border: 1px solid #6cb2eb;
#             border-radius: 5px;
#             margin-top: 5px;
#         }
#         .btn {
#             background-color: #007bff;
#             color: white;
#             border: none;
#             padding: 10px 15px;
#             cursor: pointer;
#             border-radius: 5px;
#             margin-top: 5px;
#             transition: background-color 0.3s;
#             width: 100%;
#             text-align: left; /* Align text to the left */
#         }
#         .btn:hover {
#             background-color: #0056b3;
#         }
#     </style>
# </head>
# <body>
#
# <h2>AP Computer Science Flashcards</h2>
#
# <div class="flashcard">
#     <button class="btn" onclick="toggleVisibility('variablesContent')">Data Holders</button>
#     <div id="variablesContent" class="content">
#         <pre>
# # Variables
# age_value = 15
# name_value = "Alex"
# print(name_value)
# print(age_value)
# # Output:
# # Alex
# # 15
#         </pre>
#     </div>
# </div>
#
# <div class="flashcard">
#     <button class="btn" onclick="toggleVisibility('variableNamingContent')">Name Styles</button>
#     <div id="variableNamingContent" class="content">
#         <pre>
# # Naming Styles
# user_one = "John"
# UserTwo = "Doe"
# print(user_one)
# print(UserTwo)
# # Output:
# # John
# # Doe
#         </pre>
#     </div>
# </div>
#
# <div class="flashcard">
#     <button class="btn" onclick="toggleVisibility('dataTypesContent')">Type Definitions</button>
#     <div id="dataTypesContent" class="content">
#         <pre>
# # Data Types
# number_int = 42
# decimal_float = 3.14
# print(number_int)
# print(decimal_float)
# # Output:
# # 42
# # 3.14
#         </pre>
#     </div>
# </div>
#
# <div class="flashcard">
#     <button class="btn" onclick="toggleVisibility('dataGroupsContent')">Data Collections</button>
#     <div id="dataGroupsContent" class="content">
#         <pre>
# # Lists
# group_names = ["Alice", "Bob", "Charlie"]
# print(group_names[1])
# # Output:
# # Bob
#         </pre>
#     </div>
# </div>
#
# <div class="flashcard">
#     <button class="btn" onclick="toggleVisibility('keyValuePairsContent')">Associative Structures</button>
#     <div id="keyValuePairsContent" class="content">
#         <pre>
# # Dictionaries
# student_data = {"name": "Chris", "age": 17}
# print(student_data["name"])
# # Output:
# # Chris
#         </pre>
#     </div>
# </div>
#
# <div class="flashcard">
#     <button class="btn" onclick="toggleVisibility('mathOperationsContent')">Calculative Symbols</button>
#     <div id="mathOperationsContent" class="content">
#         <pre>
# # Operators
# a = 10
# b = 5
# print(a + b)  # Addition
# print(a * b)  # Multiplication
# # Output:
# # 15
# # 50
#         </pre>
#     </div>
# </div>
#
# <div class="flashcard">
#     <button class="btn" onclick="toggleVisibility('integerTypeContent')">Whole Numbers</button>
#     <div id="integerTypeContent" class="content">
#         <pre>
# # Integers
# num_one = 10
# num_two = -5
# print(num_one)
# print(num_two)
# # Output:
# # 10
# # -5
#         </pre>
#     </div>
# </div>
#
# <div class="flashcard">
#     <button class="btn" onclick="toggleVisibility('floatTypeContent')">Decimal Numbers</button>
#     <div id="floatTypeContent" class="content">
#         <pre>
# # Floats
# pi_value = 3.14159
# print(pi_value)
# # Output:
# # 3.14159
#         </pre>
#     </div>
# </div>
#
# <div class="flashcard">
#     <button class="btn" onclick="toggleVisibility('stringTypeContent')">Text Values</button>
#     <div id="stringTypeContent" class="content">
#         <pre>
# # Strings
# message = "Hello, World!"
# print(message)
# # Output:
# # Hello, World!
#         </pre>
#     </div>
# </div>
#
# <div class="flashcard">
#     <button class="btn" onclick="toggleVisibility('booleanTypeContent')">True/False Indicators</button>
#     <div id="booleanTypeContent" class="content">
#         <pre>
# # Booleans
# is_active = True
# print(is_active)
# # Output:
# # True
#         </pre>
#     </div>
# </div>
#
# <div class="flashcard">
#     <button class="btn" onclick="toggleVisibility('noneTypeContent')">Null Values</button>
#     <div id="noneTypeContent" class="content">
#         <pre>
# # None Type
# variable = None
# print("Value:", variable)
# if variable is None:
#     print("It's None!")
# # Output:
# # Value: None
# # It's None!
#         </pre>
#     </div>
# </div>
#
# <div class="flashcard">
#     <button class="btn" onclick="toggleVisibility('mathExpressionsContent')">Mathematical Expressions</button>
#     <div id="mathExpressionsContent" class="content">
#         <pre>
# # Mathematical Expressions
# x = (5 + 3) * 2
# y = 12 / 4 - 1
# print("x =", x)  # Output: 16
# print("y =", y)  # Output: 2.0
#         </pre>
#     </div>
# </div>
#
# <div class="flashcard">
#     <button class="btn" onclick="toggleVisibility('pythonStringsContent')">Python Strings</button>
#     <div id="pythonStringsContent" class="content">
#         <pre>
# # Python Strings
# greeting = "Welcome to Python!"
# print(greeting)
# # Output:
# # Welcome to Python!
#
# # Multi-line Strings
# multiline_message = """This is a
# multi-line string."""
# print(multiline_message)
# # Output:
# # This is a
# # multi-line string.
#         </pre>
#     </div>
# </div>
#
# <div class="flashcard">
#     <button class="btn" onclick="toggleVisibility('javascriptStringsContent')">JavaScript Strings</button>
#     <div id="javascriptStringsContent" class="content">
#         <pre>
# /* JavaScript Strings */
# let greeting = "Hello from JavaScript!";
# console.log(greeting);
# // Output:
# // Hello from JavaScript!
#
# // Multi-line Strings
# let multilineMessage = `This is a
# multi-line string.`;
# console.log(multilineMessage);
# // Output:
# // This is a
# // multi-line string.
#         </pre>
#     </div>
# </div>
#
# <div class="flashcard">
#     <button class="btn" onclick="toggleVisibility('ifElseStatementsContent')">Conditional Logic</button>
#     <div id="ifElseStatementsContent" class="content">
#         <pre>
# # If/Else Statements
# # Python Example
# age = 18
# if age >= 18:
#     print("You are an adult.")
# else:
#     print("You are a minor.")
# # Output:
# # You are an adult.
#
# # JavaScript Example
# let age = 16;
# if (age >= 18) {
#     console.log("You are an adult.");
# } else {
#     console.log("You are a minor.");
# }
# // Output:
# // You are a minor.
#         </pre>
#     </div>
# </div>
#
# <script>
#     function toggleVisibility(contentId) {
#         const content = document.getElementById(contentId);
#         if (content.style.display === "block") {
#             content.style.display = "none";
#         } else {
#             content.style.display = "block";
#         }
#     }
# </script>
#
# </body>
# </html>

# %% [markdown]
# <style>
#     body {
#         background-color: #2e3440;  /* Dark background */
#         color: white;               /* White text */
#     }
#
#     div.code_cell {
#         background-color: #282a36;  /* Dark theme for code cells */
#         color: white;               /* White text for code cells */
#         border-radius: 10px;
#         padding: 10px;
#     }
#
#     div.markdown_cell {
#         background-color: #44475a;  /* Dark theme for markdown cells */
#         color: white;               /* White text for markdown cells */
#         border-radius: 10px;
#         padding: 10px;
#     }
#     </style>
